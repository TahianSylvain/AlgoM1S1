# %%
import pandas as pd

data = pd.read_csv("instat-tp2.csv")

data = data.fillna("") # visually clear NaN cells
data
# Out:
#                  Region Urbain Masculin  ... Quintile Plus Riche Quintile Ensemble
# 0            Analamanga            56,9  ...                61,8              49,2
# 1         Vakinakaratra            43,2  ...                62,6              23,3
# 2                 Itasy            50,6  ...                62,8              22,4
# 3             Bongolava            46,8  ...                61,4              20,1
# 4       Haute Matsiatra            49,6  ...                65,4              24,7
# 5        Amoron'i Mania            39,1  ...                60,4              20,3
# 6   Vatovavy Fitovinany            38,7  ...                52,2              13,8
# 7              Ihorombe            32,2  ...                50,3              12,9
# 8     Atsimo Atsinanana              40  ...                  48              12,4
# 9            Atsinanana            45,7  ...                54,9              21,5
# ...

# %% [markdown]
# L'ensemble de données ici présentée est en provenance de l'INSTAT MADAGASCAR. Il recense le Recensement Général de la Population et de l'Habitation (RGPH) en l'an 2018.
#
# ## Structure

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Region                22 non-null     object
#  1   Urbain Masculin       22 non-null     object
#  2   Urbain Feminin        22 non-null     object
#  3   Urbain Total          22 non-null     object
#  4   Rural Masculin        22 non-null     object
#  5   Rural Feminin         22 non-null     object
#  6   Rural Total           22 non-null     object
#  7   Total Masculin        22 non-null     object
#  8   Total Feminin         22 non-null     object
#  9   Total Total           22 non-null     object
#  10  Quintile Plus Pauvre  22 non-null     object
#  11  Quintile 2eme         22 non-null     object
#  12  Quintile 3eme         22 non-null     object
#  13  Quintile 4eme         22 non-null     object
#  14  Quintile Plus Riche   22 non-null     object
# ...

# %%
# import seaborn as sbn 
# sbn.pairplot(data)
data.describe()
# data.plot()
# Out:
#             Region Urbain Masculin  ... Quintile Plus Riche Quintile Ensemble
# count           22              22  ...                  22                22
# unique          22              22  ...                  22                22
# top     Analamanga            56,9  ...                61,8              49,2
# freq             1               1  ...                   1                 1
#
# [4 rows x 16 columns]
